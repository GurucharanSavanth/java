# %%
import numpy as np

# %%
def unitStep(v):
  if v >=0:
    return 1
  else:
    return 0

# %%
def perceptronModel(x,w,b):
  v=np.dot(w,x)+b
  y=unitStep(v)
  return y

# %%
def OR_logicFunction(x):
  weights=[1,1]
  bias=-0.5
  return perceptronModel(x,weights,bias)

# %%
def AND_logicFunction(x):
  weights=[1,1]
  bias=-1.5
  return perceptronModel(x,weights,bias)

# %%
def XOR_logicFunction(x):
  weights=[1,1]
  bias=-1
  return perceptronModel(x,weights,bias)

# %%
def XNOR_logicFunction(x):
  weights=[1,1]
  bias=-0.5
  return perceptronModel(x,weights,bias)

# %%
test1=np.array([1,0])
test2=np.array([1,1])
test3=np.array([1,1])
test4=np.array([1,0])

# %%
print("OR({})={}".format(test1,OR_logicFunction(test1)))
print("AND({})={}".format(test2,AND_logicFunction(test2)))
print("XOR({})={}".format(test3,XOR_logicFunction(test3)))
print("XNOR({})={}".format(test4,XNOR_logicFunction(test4)))
# Out:
# OR([1 0])=1
# AND([1 1])=1
# XOR([1 1])=1
# XNOR([1 0])=1

# %%
import numpy as np

def unitStep(v):
   if v >= 0:
       return 1
   else:
       return 0

def perceptronModel(x, w, b):
   v = np.dot(w, x) + b
   y = unitStep(v)
   return y

def NOT_logicFunction(x):
    wNOT = -1
    bNOT = 0.5
    return perceptronModel(x, wNOT, bNOT)

def AND_logicFunction(x):
    w = np.array([1, 1])
    bAND = -1.5
    return perceptronModel(x, w, bAND)

def OR_logicFunction(x):
    w = np.array([1, 1])
    bOR = -0.5
    return perceptronModel(x, w, bOR)

def OR_logicFunction(x):
   weights = [1, 1]
   bias = -0.5
   return perceptronModel(x, weights, bias)

def AND_logicFunction(x):
   weights = [1, 1]
   bias = -1.5
   return perceptronModel(x, weights, bias)

def XOR_logicFunction(x):
    y1 = AND_logicFunction(x)
    y2 = OR_logicFunction(x)
    y3 = NOT_logicFunction(y1)
    final_x = np.array([y2, y3])
    finalOutput = AND_logicFunction(final_x)
    return finalOutput

def XNOR_logicFunction(x):
   weights = [1, 1]
   bias = -1
   return perceptronModel(x, weights, bias)


test1 = np.array([1, 1])
test2 = np.array([0, 1])
test3 = np.array([0, 0])
test4 = np.array([1, 1])


print("OR({}) = {}".format(test1, OR_logicFunction(test1)))
print("AND({}) = {}".format(test2, AND_logicFunction(test2)))
print("XOR({}) = {}".format(test3, XOR_logicFunction(test3)))
print("XNOR({}) = {}".format(test4, XNOR_logicFunction(test4)))
# Out:
# OR([1 1]) = 1
# AND([0 1]) = 0
# XOR([0 0]) = 0
# XNOR([1 1]) = 1

# %% [markdown]
# XNOR EDITED

# %%
import numpy as np

def unitStep(v):
   if v >= 0:
       return 1
   else:
       return 0

def perceptronModel(x, w, b):
   v = np.dot(w, x) + b
   y = unitStep(v)
   return y

def NOT_logicFunction(x):
    wNOT = -1
    bNOT = 0.5
    return perceptronModel(x, wNOT, bNOT)

def AND_logicFunction(x):
    w = np.array([1, 1])
    bAND = -1.5
    return perceptronModel(x, w, bAND)

def OR_logicFunction(x):
    w = np.array([1, 1])
    bOR = -0.5
    return perceptronModel(x, w, bOR)

def OR_logicFunction(x):
   weights = [1, 1]
   bias = -0.5
   return perceptronModel(x, weights, bias)

def AND_logicFunction(x):
   weights = [1, 1]
   bias = -1.5
   return perceptronModel(x, weights, bias)

def XOR_logicFunction(x):
    y1 = AND_logicFunction(x)
    y2 = OR_logicFunction(x)
    y3 = NOT_logicFunction(y1)
    final_x = np.array([y2, y3])
    finalOutput = AND_logicFunction(final_x)
    return finalOutput

def XNOR_logicFunction(x):
    y1 = AND_logicFunction(x)
    y2 = OR_logicFunction(x)
    y3 = NOT_logicFunction(y1)
    final_x = np.array([y2, y3])
    finalOutput = AND_logicFunction(final_x)
    testcase = NOT_logicFunction(finalOutput)
    return testcase


test1 = np.array([1, 0])
test2 = np.array([0, 1])
test3 = np.array([1, 1])
test4 = np.array([1, 0])


print("OR({}) = {}".format(test1, OR_logicFunction(test1)))
print("AND({}) = {}".format(test2, AND_logicFunction(test2)))
print("XOR({}) = {}".format(test3, XOR_logicFunction(test3)))
print("XNOR({}) = {}".format(test4, XNOR_logicFunction(test4)))
# Out:
# OR([1 0]) = 1
# AND([0 1]) = 0
# XOR([1 1]) = 0
# XNOR([1 0]) = 0

# %%
import numpy as np

def unitStep(v):
   if v >= 0:
       return 1
   else:
       return 0

def perceptronModel(x, w, b):
   v = np.dot(w, x) + b
   y = unitStep(v)
   return y

def NOT_logicFunction(x):
    wNOT = -1
    bNOT = 0.5
    return perceptronModel(x, wNOT, bNOT)

def AND_logicFunction(x):
    w = np.array([1, 1])
    bAND = -1.5
    return perceptronModel(x, w, bAND)

def OR_logicFunction(x):
    w = np.array([1, 1])
    bOR = -0.5
    return perceptronModel(x, w, bOR)

def OR_logicFunction(x):
   weights = [1, 1]
   bias = -0.5
   return perceptronModel(x, weights, bias)

def AND_logicFunction(x):
   weights = [1, 1]
   bias = -1.5
   return perceptronModel(x, weights, bias)

def XOR_logicFunction(x):
    y1 = AND_logicFunction(x)
    y2 = OR_logicFunction(x)
    y3 = NOT_logicFunction(y1)
    final_x = np.array([y2, y3])
    finalOutput = AND_logicFunction(final_x)
    return finalOutput

def XNOR_logicFunction(x):
   weights = [1, 1]
   bias = -1
   return perceptronModel(x, weights, bias)


test1 = np.array([1, 1])
test2 = np.array([0, 1])
test3 = np.array([0, 0])
test4 = np.array([1, 1])


print("XOR({}) = {}".format(test1, XOR_logicFunction(test1)))
print("XOR({}) = {}".format(test2, XOR_logicFunction(test2)))
print("XOR({}) = {}".format(test3, XOR_logicFunction(test3)))
print("XOR({}) = {}".format(test4, XOR_logicFunction(test4)))
# Out:
# XOR([1 1]) = 0
# XOR([0 1]) = 1
# XOR([0 0]) = 0
# XOR([1 1]) = 0
